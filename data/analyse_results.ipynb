# %%
import pandas as pd

data = pd.read_csv("candidate_votes.csv")
data[["booth", "party", "votes"]].groupby(["booth", "party"]).sum().to_csv("booth_results.csv")
data = pd.read_csv("booth_results.csv")

parties = data["party"].unique()
booths = data["booth"].unique()
booth_results = pd.DataFrame(columns=parties, index=booths)

for booth in booths:
    results = []
    for party in parties:
        results.append(data[data.booth.eq(booth) & data.party.eq(party)].votes.sum())
    booth_results.loc[booth] = results

booth_results["formal votes"] = booth_results.sum(axis=1)

for booth in booth_results.index:
    if "(Early voting)" in booth:
        booth_results.loc[booth.replace(" (Early voting)", "")] = booth_results.loc[booth.replace(" (Early voting)", "")] + booth_results.loc[booth]
        print(booth)

for index, row in booth_results.iterrows():
    for party in booth_results.columns[:-1]:
        booth_results.loc[index, party] = row[party] / row["formal votes"]

# for index, row in booth_results2016.iterrows():
#     for party in booth_results2016.columns[:-1]:
#         booth_results2016.loc[index, party] = row[party] / row["formal votes"]
        
booth_results
# Out:
# Belconnen (Early voting)
# Chisholm (Early voting)
# City (Early voting)
# Dickson (Early voting)
# Flynn (Early voting)
# Gungahlin North (Early voting)
# Gungahlin West (Early voting)
# Harrison (Early voting)
# Kippax (Early voting)
# Lanyon (Early voting)
# Manuka (Early voting)
# Tuggeranong (Early voting)
# Weston Creek (Early voting)
# Woden (Early voting)
#                             ACT Labor Animal Justice Party  \
# Ainslie                      0.407767            0.0167696
# Ainslie North                0.361852            0.0243328
# Amaroo                       0.390465             0.015891
# Aranda                       0.440338            0.0253432
# Belconnen                    0.389939               0.0158
# ...                               ...                  ...
# Weston Creek                 0.370228            0.0166251
# Weston Creek (Early voting)  0.368824            0.0161301
# Woden                        0.375379            0.0187441
# Woden (Early voting)         0.375447            0.0184715
# Yarralumla                   0.263309             0.018705
#
#                             Australian Climate Change Justice Party  \
# Ainslie                                                    0.011474
# Ainslie North                                             0.0149137
# Amaroo                                                   0.00113507
# Aranda                                                    0.0105597
# Belconnen                                                0.00991125
# ...                                                             ...
# Weston Creek                                              0.0106145
# Weston Creek (Early voting)                               0.0100305
# Woden                                                    0.00891927
# Woden (Early voting)                                     0.00878925
# Yarralumla                                                0.0158273
#
#                             Australian Federation Party Australian Capital Territory  \
# Ainslie                                                                      0
# Ainslie North                                                                0
# Amaroo                                                              0.00340522
# Aranda                                                                       0
# Belconnen                                                          0.000248818
# ...                                                                        ...
# Weston Creek                                                       0.000575484
# Weston Creek (Early voting)                                        0.000542189
# Woden                                                               0.00117716
# Woden (Early voting)                                                0.00117503
# Yarralumla                                                                   0
#
#                              Belco Party Canberra Liberals  \
# Ainslie                       0.00441306          0.195057
# Ainslie North                 0.00156986          0.174254
# Amaroo                                 0          0.374574
# Aranda                         0.0432946          0.176346
# Belconnen                      0.0656465          0.284938
# ...                                  ...               ...
# Weston Creek                 0.000959141            0.3662
# Weston Creek (Early voting)  0.000948831          0.370451
# Woden                         0.00190157          0.342419
# Woden (Early voting)          0.00197406          0.344332
# Yarralumla                             0          0.423022
#
#                             Canberra Progressives David Pollard Independent  \
# Ainslie                                 0.0529568                         0
# Ainslie North                           0.0533752               0.000784929
# Amaroo                                  0.0272418                 0.0227015
# Aranda                                 0.00211193                         0
# Belconnen                              0.00613751                0.00501783
# ...                                           ...                       ...
# Weston Creek                            0.0240425               0.000447599
# Weston Creek (Early voting)             0.0241274               0.000406642
# Woden                                   0.0256712               0.000588582
# Woden (Early voting)                    0.0254277               0.000517014
# Yarralumla                               0.028777                         0
#
#                               Labour DLP Liberal Democrats  \
# Ainslie                       0.00264784                 0
# Ainslie North                 0.00313972                 0
# Amaroo                         0.0442679        0.00113507
# Aranda                         0.0095037        0.00422386
# Belconnen                      0.0311852        0.00792071
# ...                                  ...               ...
# Weston Creek                  0.00127885        0.00070337
# Weston Creek (Early voting)  0.000948831        0.00074551
# Woden                         0.00253543        0.00280708
# Woden (Early voting)          0.00258507        0.00272608
# Yarralumla                             0                 0
#
#                             Shooters, Fishers and Farmers Party (ACT)  \
# Ainslie                                                   0.000882613
# Ainslie North                                                       0
# Amaroo                                                              0
# Aranda                                                     0.00844773
# Belconnen                                                   0.0148461
# ...                                                               ...
# Weston Creek                                                0.0128525
# Weston Creek (Early voting)                                 0.0124026
# Woden                                                       0.0102323
# Woden (Early voting)                                        0.0101053
# Yarralumla                                                 0.00719424
#
#                             Sustainable Australia - Stop overdevelopment. Stop corruption.  \
# Ainslie                                                              0.0211827
# Ainslie North                                                        0.0172684
# Amaroo                                                               0.0102157
# Aranda                                                               0.0253432
# Belconnen                                                            0.0177076
# ...                                                                        ...
# Weston Creek                                                         0.0154102
# Weston Creek (Early voting)                                          0.0152491
# Woden                                                                0.0160275
# Woden (Early voting)                                                 0.0158394
# Yarralumla                                                           0.0201439
#
#                             The ACT Greens The Community Action Party (ACT)  \
# Ainslie                           0.264784                       0.00617829
# Ainslie North                       0.3281                       0.00470958
# Amaroo                           0.0976163                                0
# Aranda                            0.241816                                0
# Belconnen                          0.13573                      0.000124409
# ...                                    ...                              ...
# Weston Creek                      0.112603                      0.000127885
# Weston Creek (Early voting)       0.110878                      0.000135547
# Woden                             0.121791                      0.000135827
# Woden (Early voting)              0.119618                      0.000141004
# Yarralumla                        0.130935                                0
#
#                              Ungrouped  formal votes
# Ainslie                       0.015887        1133.0
# Ainslie North                0.0156986        1274.0
# Amaroo                       0.0113507         881.0
# Aranda                       0.0126716         947.0
# Belconnen                    0.0148461       24114.0
# ...                                ...           ...
# Weston Creek                 0.0673317       15639.0
# Weston Creek (Early voting)  0.0681803       14755.0
# Woden                        0.0716711       22087.0
# Woden (Early voting)          0.072852       21276.0
# Yarralumla                   0.0920863         695.0
#
# [101 rows x 16 columns]

# %%
for column in booth_results.columns[:-1]:
    booth_results[column] = booth_results[column].astype("float")    
# for column in booth_results2016.columns[:-1]:
#     booth_results2016[column] = booth_results2016[column].astype("float")

# %%
booth_details = pd.read_csv("booth_details2020.csv", index_col="Name")
booth_details["lng"] = booth_details["Coordinates"].apply(lambda x: x.split(",")[-1].strip()[5:]).astype("float")
booth_details["lat"] = booth_details["Coordinates"].apply(lambda x: x.split(",")[0].strip()[5:]).astype("float")
new_index = []
for booth in booth_details.index:
    if "Gungahlin City" in booth:
        booth = booth.replace(" City", "")
    new_index.append(booth)
booth_details.index = new_index

locations = []
for booth in booth_results.index:
    if booth in booth_details.index:
        locations.append([booth_details.loc[booth, "lng"], booth_details.loc[booth, "lat"]])
    else:
        locations.append("NaN")
booth_results["location"] = locations
booth_results
# Out:
#                              ACT Labor  Animal Justice Party  \
# Ainslie                       0.407767              0.016770
# Ainslie North                 0.361852              0.024333
# Amaroo                        0.390465              0.015891
# Aranda                        0.440338              0.025343
# Belconnen                     0.389939              0.015800
# ...                                ...                   ...
# Weston Creek                  0.370228              0.016625
# Weston Creek (Early voting)   0.368824              0.016130
# Woden                         0.375379              0.018744
# Woden (Early voting)          0.375447              0.018472
# Yarralumla                    0.263309              0.018705
#
#                              Australian Climate Change Justice Party  \
# Ainslie                                                     0.011474
# Ainslie North                                               0.014914
# Amaroo                                                      0.001135
# Aranda                                                      0.010560
# Belconnen                                                   0.009911
# ...                                                              ...
# Weston Creek                                                0.010614
# Weston Creek (Early voting)                                 0.010030
# Woden                                                       0.008919
# Woden (Early voting)                                        0.008789
# Yarralumla                                                  0.015827
#
#                              Australian Federation Party Australian Capital Territory  \
# Ainslie                                                               0.000000
# Ainslie North                                                         0.000000
# Amaroo                                                                0.003405
# Aranda                                                                0.000000
# Belconnen                                                             0.000249
# ...                                                                        ...
# Weston Creek                                                          0.000575
# Weston Creek (Early voting)                                           0.000542
# Woden                                                                 0.001177
# Woden (Early voting)                                                  0.001175
# Yarralumla                                                            0.000000
#
#                              Belco Party  Canberra Liberals  \
# Ainslie                         0.004413           0.195057
# Ainslie North                   0.001570           0.174254
# Amaroo                          0.000000           0.374574
# Aranda                          0.043295           0.176346
# Belconnen                       0.065647           0.284938
# ...                                  ...                ...
# Weston Creek                    0.000959           0.366200
# Weston Creek (Early voting)     0.000949           0.370451
# Woden                           0.001902           0.342419
# Woden (Early voting)            0.001974           0.344332
# Yarralumla                      0.000000           0.423022
#
#                              Canberra Progressives  David Pollard Independent  \
# Ainslie                                   0.052957                   0.000000
# Ainslie North                             0.053375                   0.000785
# Amaroo                                    0.027242                   0.022701
# Aranda                                    0.002112                   0.000000
# Belconnen                                 0.006138                   0.005018
# ...                                            ...                        ...
# Weston Creek                              0.024042                   0.000448
# Weston Creek (Early voting)               0.024127                   0.000407
# Woden                                     0.025671                   0.000589
# Woden (Early voting)                      0.025428                   0.000517
# Yarralumla                                0.028777                   0.000000
#
#                              Labour DLP  Liberal Democrats  \
# Ainslie                        0.002648           0.000000
# Ainslie North                  0.003140           0.000000
# Amaroo                         0.044268           0.001135
# Aranda                         0.009504           0.004224
# Belconnen                      0.031185           0.007921
# ...                                 ...                ...
# Weston Creek                   0.001279           0.000703
# Weston Creek (Early voting)    0.000949           0.000746
# Woden                          0.002535           0.002807
# Woden (Early voting)           0.002585           0.002726
# Yarralumla                     0.000000           0.000000
#
#                              Shooters, Fishers and Farmers Party (ACT)  \
# Ainslie                                                       0.000883
# Ainslie North                                                 0.000000
# Amaroo                                                        0.000000
# Aranda                                                        0.008448
# Belconnen                                                     0.014846
# ...                                                                ...
# Weston Creek                                                  0.012852
# Weston Creek (Early voting)                                   0.012403
# Woden                                                         0.010232
# Woden (Early voting)                                          0.010105
# Yarralumla                                                    0.007194
#
#                              Sustainable Australia - Stop overdevelopment. Stop corruption.  \
# Ainslie                                                               0.021183
# Ainslie North                                                         0.017268
# Amaroo                                                                0.010216
# Aranda                                                                0.025343
# Belconnen                                                             0.017708
# ...                                                                        ...
# Weston Creek                                                          0.015410
# Weston Creek (Early voting)                                           0.015249
# Woden                                                                 0.016028
# Woden (Early voting)                                                  0.015839
# Yarralumla                                                            0.020144
#
#                              The ACT Greens  The Community Action Party (ACT)  \
# Ainslie                            0.264784                          0.006178
# Ainslie North                      0.328100                          0.004710
# Amaroo                             0.097616                          0.000000
# Aranda                             0.241816                          0.000000
# Belconnen                          0.135730                          0.000124
# ...                                     ...                               ...
# Weston Creek                       0.112603                          0.000128
# Weston Creek (Early voting)        0.110878                          0.000136
# Woden                              0.121791                          0.000136
# Woden (Early voting)               0.119618                          0.000141
# Yarralumla                         0.130935                          0.000000
#
#                              Ungrouped  formal votes                  location
# Ainslie                       0.015887        1133.0   [149.14173, -35.273299]
# Ainslie North                 0.015699        1274.0  [149.147507, -35.255295]
# Amaroo                        0.011351         881.0  [149.128387, -35.164513]
# Aranda                        0.012672         947.0  [149.080322, -35.255314]
# Belconnen                     0.014846       24114.0   [149.070362, -35.23915]
# ...                                ...           ...                       ...
# Weston Creek                  0.067332       15639.0  [149.052064, -35.341953]
# Weston Creek (Early voting)   0.068180       14755.0                       NaN
# Woden                         0.071671       22087.0   [149.088493, -35.34576]
# Woden (Early voting)          0.072852       21276.0                       NaN
# Yarralumla                    0.092086         695.0   [149.102264, -35.30661]
#
# [101 rows x 17 columns]

# %%
booth_results["other"] = 1 - (booth_results["ACT Labor"] + booth_results["The ACT Greens"] + booth_results["Canberra Liberals"])
results = booth_results[["ACT Labor", "Canberra Liberals", "The ACT Greens", "other", "formal votes", "location"]]
results.columns = ["labor", "liberals", "greens", "other", "votes", "location"]
results.to_csv("results.csv", index_label="booth")
results
# Out:
#                                 labor  liberals    greens     other    votes  \
# Ainslie                      0.407767  0.195057  0.264784  0.132392   1133.0
# Ainslie North                0.361852  0.174254  0.328100  0.135793   1274.0
# Amaroo                       0.390465  0.374574  0.097616  0.137344    881.0
# Aranda                       0.440338  0.176346  0.241816  0.141499    947.0
# Belconnen                    0.389939  0.284938  0.135730  0.189392  24114.0
# ...                               ...       ...       ...       ...      ...
# Weston Creek                 0.370228  0.366200  0.112603  0.150969  15639.0
# Weston Creek (Early voting)  0.368824  0.370451  0.110878  0.149848  14755.0
# Woden                        0.375379  0.342419  0.121791  0.160411  22087.0
# Woden (Early voting)         0.375447  0.344332  0.119618  0.160603  21276.0
# Yarralumla                   0.263309  0.423022  0.130935  0.182734    695.0
#
#                                              location
# Ainslie                       [149.14173, -35.273299]
# Ainslie North                [149.147507, -35.255295]
# Amaroo                       [149.128387, -35.164513]
# Aranda                       [149.080322, -35.255314]
# Belconnen                     [149.070362, -35.23915]
# ...                                               ...
# Weston Creek                 [149.052064, -35.341953]
# Weston Creek (Early voting)                       NaN
# Woden                         [149.088493, -35.34576]
# Woden (Early voting)                              NaN
# Yarralumla                    [149.102264, -35.30661]
#
# [101 rows x 6 columns]

# %%
results["votes"]
# Out:
# Ainslie                         1133.0
# Ainslie North                   1274.0
# Amaroo                           881.0
# Aranda                           947.0
# Belconnen                      24114.0
#                                 ...
# Weston Creek                   15639.0
# Weston Creek (Early voting)    14755.0
# Woden                          22087.0
# Woden (Early voting)           21276.0
# Yarralumla                       695.0
# Name: votes, Length: 101, dtype: float64
